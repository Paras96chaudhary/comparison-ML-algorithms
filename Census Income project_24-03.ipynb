# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
#Reading the data

df = pd.read_csv('census-income[1].csv')

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.describe(include="all")
# Out:
#                  age workclass        fnlwgt education  education-num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital-status      occupation relationship   race    sex  \
# ...

# %%
# Filter the DataFrame for income greater than 50K
population_greater_than_50k = df[df['annual_income'] == '>50K']

# Count the number of rows
total_population_greater_than_50k = population_greater_than_50k.shape[0]

# Display the result
print("Total population with income greater than 50% income:", total_population_greater_than_50k)
# Out:
# Total population with income greater than 50% income: 7841

# %%
# Calculate the percentage
percentage_greater_than_50k = (7841 / 32561) * 100

# Display the result
print("Percentage of population with income greater than 50% income:", percentage_greater_than_50k)
# Out:
# Percentage of population with income greater than 50% income: 24.080955744602438

# %%
poplu_unmarr=df[(df['marital-status']!='Married-civ-spouse')& (df['hours-per-week']<20)]
total_poplu_unmar= poplu_unmarr.shape[0]
print('total_poplu_unmar:',total_poplu_unmar)
# Out:
# total_poplu_unmar: 1244

# %%
# Extract the age column from the DataFrame
age_list = df['age']

# Calculate the minimum, maximum, and 50th percentile (median)
age_min = age_list.min()
age_max = age_list.max()
age_median = age_list.median()

# Create a list with the results
age_stats = [age_min, age_max, age_median]

# Display the list
print("Minimum age, maximum age, and 50th percentile of the age group:", age_stats)
# Out:
# Minimum age, maximum age, and 50th percentile of the age group: [17, 90, 37.0]

# %%
df['native-country'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# annual_income     object
# dtype: object

# %%
#np.where
df['annual_income'] = np.where(df['annual_income']=='>50K', 1, 0)

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country  annual_income
# 0          2174             0              40  United-States              0
# ...

# %%
df['annual_income'] = df['annual_income'].astype(str)

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# annual_income     object
# dtype: object

# %%
#checking for null values
df.isnull()
# Out:
#          age  workclass  fnlwgt  education  education-num  marital-status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
# 32560  False      False   False      False          False           False
#
#        occupation  relationship   race    sex  capital-gain  capital-loss  \
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# annual_income     0
# dtype: int64

# %%
df['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df.loc[df['workclass']=='?']
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 27      54         ?  180211  Some-college             10
# 61      32         ?  293936       7th-8th              4
# 69      25         ?  200681  Some-college             10
# 77      67         ?  212759          10th              6
# 106     17         ?  304873          10th              6
# ...    ...       ...     ...           ...            ...
# 32530   35         ?  320084     Bachelors             13
# 32531   30         ?   33811     Bachelors             13
# 32539   71         ?  287372     Doctorate             16
# 32541   41         ?  202822       HS-grad              9
# 32542   72         ?  129912       HS-grad              9
#
#               marital-status occupation   relationship                race  \
# 27        Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent          ?  Not-in-family               White
# ...

# %%
df.loc[df['occupation']=='?']
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 27      54         ?  180211  Some-college             10
# 61      32         ?  293936       7th-8th              4
# 69      25         ?  200681  Some-college             10
# 77      67         ?  212759          10th              6
# 106     17         ?  304873          10th              6
# ...    ...       ...     ...           ...            ...
# 32530   35         ?  320084     Bachelors             13
# 32531   30         ?   33811     Bachelors             13
# 32539   71         ?  287372     Doctorate             16
# 32541   41         ?  202822       HS-grad              9
# 32542   72         ?  129912       HS-grad              9
#
#               marital-status occupation   relationship                race  \
# 27        Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent          ?  Not-in-family               White
# ...

# %%
#workclass - private and native country - united states

df[(df['workclass']=='Private') & (df['native-country']=='United-States')]
# Out:
#        age workclass  fnlwgt     education  education-num      marital-status  \
# 2       38   Private  215646       HS-grad              9            Divorced
# 3       53   Private  234721          11th              7  Married-civ-spouse
# 5       37   Private  284582       Masters             14  Married-civ-spouse
# 8       31   Private   45781       Masters             14       Never-married
# 9       42   Private  159449     Bachelors             13  Married-civ-spouse
# ...    ...       ...     ...           ...            ...                 ...
# 32555   22   Private  310152  Some-college             10       Never-married
# 32556   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32557   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32558   58   Private  151910       HS-grad              9             Widowed
# 32559   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  annual_income   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#drop
df.drop(df[df['workclass']=='?'].index, inplace = True)

# %%
df.drop(df[df['occupation']=='?'].index, inplace = True)

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.shape
# Out:
# (30718, 15)

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# annual_income     object
# dtype: object

# %%
#one hot encoding
#Label Encoding

# %%
#Label Encoding is used to convert object to numeric values

# %%
col_list = []
for col in df.columns:
    if ((df[col].dtype=='object') & (col!='annual_income')):
        col_list.append(col)

# %%
col_list
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country']

# %%
#importing Label Encoder
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder() #create an object
for i in col_list:
    df[i] = labelencoder.fit_transform(df[i])

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          5   77516          9             13               4
# 1   50          4   83311          9             13               2
# 2   38          2  215646         11              9               0
# 3   53          2  234721          1              7               2
# 4   28          2  338409          9             13               2
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           0             1     4    1          2174             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
#
#    hours-per-week  native-country annual_income
# 0              40              39             0
# 1              13              39             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30718 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30718 non-null  int64
#  1   workclass       30718 non-null  int32
#  2   fnlwgt          30718 non-null  int64
#  3   education       30718 non-null  int32
#  4   education-num   30718 non-null  int64
#  5   marital-status  30718 non-null  int32
#  6   occupation      30718 non-null  int32
#  7   relationship    30718 non-null  int32
#  8   race            30718 non-null  int32
#  9   sex             30718 non-null  int32
#  10  capital-gain    30718 non-null  int64
#  11  capital-loss    30718 non-null  int64
#  12  hours-per-week  30718 non-null  int64
#  13  native-country  30718 non-null  int32
#  14  annual_income   30718 non-null  object
# dtypes: int32(8), int64(6), object(1)
# memory usage: 2.8+ MB

# %%
X = df.iloc[:,:-1] #independent columns
y = df['annual_income']
print(X.shape)
print(y.shape)
# Out:
# (30718, 14)
# (30718,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=56)

# %%
x_train
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 5535    25          2   49092          9             13               4
# 22588   36          2  207568         11              9               2
# 1729    31          2   77634          8             11               2
# 11313   19          2   66838         15             10               4
# 11739   42          1   70655         11              9               2
# ...    ...        ...     ...        ...            ...             ...
# 27369   28          4  209934          4              3               2
# 14557   22          2  359759         15             10               4
# 3485    55          2  349304          9             13               2
# 422     32          5   92003          9             13               2
# 2710    50          2   92079         15             10               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression()

# %%
#Model fitting/Training
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
test_pred = log_reg.predict(x_test)

# %%
test_pred #y_test
# Out:
# array(['0', '1', '0', ..., '0', '0', '0'], dtype=object)

# %%
from sklearn.metrics import *

# %%
c1 = confusion_matrix(y_test, test_pred)

# %%
c1
# Out:
# array([[6440,  447],
#        [1628,  701]], dtype=int64)

# %%
accuracy_score(y_test, test_pred)
# Out:
# 0.7748480902777778

# %%
x_test
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 24936   30          2  167309          9             13               2
# 7572    63          2  118798         11              9               2
# 26717   24          2  189749          1              7               2
# 17051   61          3  139391         15             10               2
# 19875   32          2  158416         11              9               0
# ...    ...        ...     ...        ...            ...             ...
# 28593   50          5  172970         11              9               2
# 1068    30          2  181651          9             13               2
# 13596   48          2  116641         11              9               0
# 625     30          2  124187         11              9               4
# 14994   25          2  178843          9             13               4
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
#log_reg.predict([[]])

# %%
### Accuracy with random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score

# Define the hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

# Create an instance of the random forest classifier
rf_classifier = RandomForestClassifier()

# Perform RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=rf_classifier, param_distributions=param_grid, scoring='accuracy', n_iter=10)
random_search.fit(x_train, y_train)  # X_train and y_train are your training data

# Access the best hyperparameters
best_params = random_search.best_params_

# Fit the model with the best hyperparameters
best_model = RandomForestClassifier(**best_params)
best_model.fit(x_train, y_train)

# Make predictions on the test data
y_pred = best_model.predict(x_test)  # X_test is your test data

# Compute the accuracy score
accuracy = accuracy_score(y_test, y_pred)  # y_test is the true labels of the test data

# Display the accuracy score
print("Accuracy score:", accuracy)
# Out:
# Accuracy score: 0.8604600694444444
